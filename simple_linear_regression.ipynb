# %%
# Simple linear regression algorithm
# Dataset consists of the day and the amount of vaccines distributed in a particular locality
# We use this algorithm to predict the future number of vaccines to be distributed according to the previous trends
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('vaccinationtrends.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
# Splitting the dataset into test and train dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
# Using Linear Regression Algorithm
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
# Plotting the Training Data onto a graph
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Vaccination Trends (Training Data)')
plt.xlabel('Day')
plt.ylabel('Vaccines Distributed')
plt.show()

# %%
# Plotting the Test Data onto a graph
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Vaccination Trends')
plt.xlabel('Day')
plt.ylabel('Vaccines Distributed')
plt.show()
